# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import string
import got3
from nltk import NaiveBayesClassifier
from nltk.corpus import stopwords 
stopwords_english = stopwords.words('english')
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
from nltk.tokenize import TweetTokenizer
from langdetect import detect
import time
import os
import io


words = ['economy','unemployment','stock market','business shutting','GDP']
count = 500

# get_tweets() will call got3 and fetch all tweets. detect() will filter tweets and saves only english tweets in the file
def get_tweets(since_date, until_date):
    path = since_date + " " + "to" + " " + until_date
    os.mkdir(path)
    placeholder = "tweets.txt"
    filename = os.path.join(path, placeholder)
    print("filename with path:", filename)
    for word in words:
        tweet_criteria = got3.manager.TweetCriteria().setSince(since_date).setUntil(until_date).setQuerySearch(word).setMaxTweets(count)
        fileio = open(filename,'a', encoding = 'utf-8')
        try:
            tweets = got3.manager.TweetManager().getTweets(tweet_criteria)
            for values in tweets:
                try:
                    if(detect(values.text) == 'en'):
                        fileio.write(values.text+'\n')
                except:
                    pass
        except:
            pass

################################################

print("Fetching the tweets")

tweets = get_tweets('2020-02-01','2020-02-02')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-02-02','2020-02-03')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-02-08','2020-02-09')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-02-09','2020-02-10')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-02-15','2020-02-16')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-02-16','2020-02-17')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-02-22','2020-02-23')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-02-23','2020-02-24')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-03-07','2020-03-08')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-03-08','2020-03-09')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-03-14','2020-03-15')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-03-15','2020-03-16')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-03-21','2020-03-22')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-03-23','2020-03-24')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-03-28','2020-03-29')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-03-30','2020-03-31')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-04-04','2020-04-05')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-04-05','2020-04-06')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-04-11','2020-04-12')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-04-12','2020-04-13')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-04-18','2020-04-19')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-04-19','2020-04-20')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-04-25','2020-04-26')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-04-26','2020-04-27')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-05-02','2020-05-03')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-05-03','2020-05-04')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-05-09','2020-05-10')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-05-10','2020-05-11')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-05-16','2020-05-17')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-05-17','2020-05-18')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-05-23','2020-05-24')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-05-24','2020-05-25')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-06-06','2020-06-07')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-06-07','2020-06-08')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-06-13','2020-06-14')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-06-14','2020-06-15')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-06-19','2020-06-20')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-06-20','2020-06-21')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-06-26','2020-06-27')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-06-27','2020-06-28')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-07-04','2020-07-05')
print("End of a day.......")
print("\n") 

tweets = get_tweets('2020-07-05','2020-07-06')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-07-10','2020-07-11')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-07-11','2020-07-12')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-07-12','2020-07-13')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-07-17','2020-07-18')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-07-18','2020-07-19')
print("End of a day.......")
print("\n")

tweets = get_tweets('2020-07-19','2020-07-20')
print("End of a day.......")
print("\n") 


print("End of tweets")
# Out:
# Fetching the tweets
# filename with path: 2020-10-01 to 2020-10-20\tweets.txt
# End of a day.......
#
#
# End of tweets
